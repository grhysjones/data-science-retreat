# %% [markdown]
# # Problem Set 1 - Regex and Tokenization
# One of the difficulties of the German langiage is the phenomena of merging together many words into one. To a newcomer to the language, this is particularly obvious and painful with numbers. For example
# * fünfhundretfünfzehn
# * achthundretzehn'
# * dreitausendvierhundretachtzehn
# * dreitausendneunhundretneunundsiebzig
# * eintausendneunhundretzweiundneunzig
#
# If we wanted to write an algorithm that took a number such as *eintausendneunhundretzweiundneunzig* and converted into 8992 we might want to start by breaking that word up into it's constituents.
# This task is an extreme example of one of the fundamental tasks in NLP, Tokenization - the act of breaking up text into it's "atomic" elements
#
# ## What we'll do
#
# The excercises in this notebook will walk you through some building block techniques in NLP, namely string searching and Regular Expressions. We'll use both techniques to try and break up the words into the most relevent tokens
# ## Prerequites
# Start by working through the amazing regex tutorial at [RegexOne](https://regexone.com/)
#
# ## Getting Data
# We've conveneiently provided a utility that will generate data for you. Run the following code to get a dictionary that maps numerical values to their verbal representation:
# **code**
# ```python
# from pprint import pprint
# from utils.numtoWord import createNum2WordDict
# d =createNum2WordDict(100,10000)
# print(d)
# ```
# **output**
# ```
# {2360: 'zweitausenddreihundretundsechzig',
#  2518: 'zweitausendfünfhundretachtzehn',
#  4080: 'viertausendundachtzig',
#  4808: 'viertausendachthundretacht',
#  5785: 'fünftausendsiebenhundretfünfundachtzig',
#  6002: 'sechstausendzwei',
#  6289: 'sechstausendzweihundretneunundachtzig',
#  7157: 'siebentausendeinhundretsiebenundfünfzig',
#  8930: 'achttausendneunhundretunddreiβig',
#  9455: 'neuntausendvierhundretfünfundfünfzig'}
# ```
#
# You want to reach soemthing that maps zweitausenddreihundretundsechzig to
# *zweitausend dreihundret und sechzig*

# %%
#Load some data
from pprint import pprint
from utils.numtoWord import createNum2WordDict
d = createNum2WordDict(size=10,high=100_000_000) # Get 10 random numbers between 0 and 10,000,000
pprint(d)
# Out:
# {16024233: 'sechszehn Million vierundzwanzigtausendzweihundretdreiunddreiβig',
#  17122466: 'siebenzehn Million '
#            'einhundretzweiundzwanzigtausendvierhundretsechsundsechzig',
#  18093898: 'achtzehn Million dreiundneunzigtausendachthundretachtundneunzig',
#  18247846: 'achtzehn Million '
#            'zweihundretsiebenundvierzigtausendachthundretsechsundvierzig',
#  44309088: 'vierundvierzig Million dreihundretneuntausendachtundachtzig',
#  57048160: 'siebenundfünfzig Million achtundvierzigtausendeinhundretundsechzig',
#  67658982: 'siebenundsechzig Million '
#            'sechshundretachtundfünfzigtausendneunhundretzweiundachtzig',
#  70265571: 'undsiebzig Million '
#            'zweihundretfünfundsechzigtausendfünfhundreteinundsiebzig',
#  87410416: 'siebenundachtzig Million '
#            'vierhundretzehntausendvierhundretsechszehn',
#  92476368: 'zweiundneunzig Million '
#            'vierhundretsechsundsiebzigtausenddreihundretachtundsechzig'}

# %%
## Excercise 1 - Naive Pattern Matching
# Sample 1000 numbers betwenn 1,100. Write a python function that will list all of the "number-names" (1-9) that appear

samples = createNum2WordDict(size=10,high=100000)
samples

def number_names(x):
    names = [x[i] for i in x]
    return names

number_names(samples)
# Out:
# ['sechsundachtzigtausendvierhundretsiebenundvierzig',
#  'sechsunddreiβigtausendneunhundretfünfundzwanzig',
#  'fünfundsiebzigtausendsiebenhundretfünfundvierzig',
#  'achtundsiebzigtausendeinhundretfünfundachtzig',
#  'dreiundneunzigtausendvierhundretsiebenundfünfzig',
#  'vierzehntausendsechshundretfünf',
#  'zehntausendfünfundsechzig',
#  'fünfzehntausendzweihundretfünfundzwanzig',
#  'achtundzwanzigtausendeinhundreteinundzwanzig',
#  'neunundvierzigtausendsechshundretdreiundsiebzig']

# %%
# Tal's Solution
import re

numMap = {
    1: 'eins',
    2: 'zwei',
    3: 'drei',
    4: 'vier',
    5: 'fünf',
    6: 'sechs',
    7: 'sieben',
    8: 'acht',
    9: 'neun',
    10: 'zehn',
    11: 'elf',
    12: 'zwölf'
}

# this is the nice regex that we can write that puts )|( between all of our dictionary values
# compiling it creates the regex phrase we can then use later
reg = re.compile('('+ ')|('.join(numMap.values()) +')')

# create a dictionary of 1000 key value pairs
d = createNum2WordDict(1000,100_000_000)

# this gets the word names of our numbers
number_names = list(d.values())

# then search for the 
reg.search(number_names[9]),number_names[9]

def getRegexMatches(x):
    results = []
    for match in reg.finditer(x):
        number = x[match.start():match.end()]
        results.append(number)
    return results

print(number_names[9])
print(getRegexMatches(number_names[9]))
# Out:
# siebenunddreiβig Million fünfhundretundachtzigtausendachthundretfünfundneunzig
# ['sieben', 'drei', 'fünf', 'acht', 'acht', 'fünf', 'neun']

# %%
# this is our nice regex function that puts our characters around the values in numMap
print(')|('.join(numMap.values()))
print('('+ ')|('.join(numMap.values()) +')')
# Out:
# eins)|(zwei)|(drei)|(vier)|(fünf)|(sechs)|(sieben)|(acht)|(neun)|(zehn)|(elf)|(zwölf
# (eins)|(zwei)|(drei)|(vier)|(fünf)|(sechs)|(sieben)|(acht)|(neun)|(zehn)|(elf)|(zwölf)

# %%
# dictionary comprehension!
final = {string:getRegexMatches(string) for string in numbers}

# %% [markdown]
# ## Excercise 2 - Smarter Pattern Matching
# Install [Py-Aho-Corasaik](https://github.com/JanFan/py-aho-corasick) and repeat excercise 1 with it

# %% [markdown]
# ## Excercise 3 - Regular Expressions
# Sample number between 1 and 1,000,000,000
# Use the python re module and the re.split function to split the numbers into millions, thousands hundrends and tens
# For example
# ```
# vierzehnmillionfünfhundreteinundzwanzigtausendvierhundretfünfzehn
# ```
# Should map to
# ```
# vierzehnmillion
# fünfhundreteinundzwanzigtausend
# vierhundret
# fünfzehn
# ```

# %%
# This was my first way of doing this, which is OK but not great

import re # this imports regex into python

x = createNum2WordDict(1,1_000_000_000)
name = number_names(x)[0]

a = re.split('( Million )',name)
b = re.split('(tausend)',a[-1])
c = re.split('(hundret)',b[-1])

print(x)

if len(a)>1:
    millions = a[0]+a[1]
    print(millions)
if len(b)>1:
    thousands = b[0]+b[1]
    print(thousands)
if len(c)>1:
    hundreds = c[0]+c[1]
    tens = c[-1]
    print(hundreds)
    print(tens)
# Out:
# {643511191: 'sechshundretdreiundvierzig Million fünfhundreteinzehntausendeinhundreteinundneunzig'}
# sechshundretdreiundvierzig Million
# fünfhundreteinzehntausend
# einhundret
# einundneunzig

# %%
# using a lookahead or lookbehind regex function is a better approach

x = createNum2WordDict(1,1_000_000_000)
name = number_names(x)[0]
print(name)

# '.+(?=Million)' this is a lookahead function. it matches any amount of anything .+ that's followed by Million
# '.+(?<=Million)' this is a lookbehind function. it does the same thing, but includes the Million in the phrase
# I can then split after this, and return what I split on by including it in brackets ()

name_list = re.split('(.+(?<=Million))(.+(?<=tausend))(.+(?<=hundret))',name)
print(name_list)

# here the {0,1} says that there may be none or there may be one 
name_list = re.split('(.+(?<=Million)){0,1}(.+(?<=tausend)){0,1}(.+(?<=hundret)){0,1}',name)

# this can also be written with ? in place of {}
name_list = re.split('(.+(?<=Million))?(.+(?<=tausend))?(.+(?<=hundret))?',name)
# Out:
# zweihundretvierundneunzig Million einhundretvierundneunzigtausendsechshundretsiebenundsiebzig
# ['', 'zweihundretvierundneunzig Million', ' einhundretvierundneunzigtausend', 'sechshundret', 'siebenundsiebzig']

# %%
# Tal's Solution
# this wasn't quite right
txt = 'zweihundretvierundneunzig Million einhundretvierundneunzigtausendsechshundretsiebenundsiebzig'

result = re.split('(hundret)|(million)|(tausend)(?!.+(million)|(tausend))',txt)
print(result)

# this step is getting rid of None's in the result
# if it gives you a truth value, then return, otherwise throw away
# None is always false, so it will throw it away
list(filter(lambda x:x,result))
# Out:
# ['zwei', 'hundret', None, None, None, None, 'vierundneunzig Million ein', 'hundret', None, None, None, None, 'vierundneunzig', None, None, 'tausend', None, None, 'sechs', 'hundret', None, None, None, None, 'siebenundsiebzig']
# ['zwei',
#  'hundret',
#  'vierundneunzig Million ein',
#  'hundret',
#  'vierundneunzig',
#  'tausend',
#  'sechs',
#  'hundret',
#  'siebenundsiebzig']

# %% [markdown]
# ## Excercise 4 - Regular Expression classifier
# We can do clever things with regular expressions. In this case we'll use regular expressions to decide if a given number is even or odd. Write a function, powered by a single regular expression, that receives a number (in word form) and returns 1 if it is even and 0 if it is odd.
# For example
# ```
# f("vierzehnmillion") =1
# f("sechshundretdreiundzwanzigtausendsechshundretneunundachtzig") =0
# ```

# %%
# this was my first attempt
import re

x = createNum2WordDict(1,1_000_000_000)
name = number_names(x)[0]
print(name)

odds = ['ein','eins','drei','fünf','sieben','neun','elf','dreizehn','fünfzehn','siebzehn','neunzehn']
evens = ['zwei','vier','sechs','acht','zehn','zwolf','vierzehn','sechszehn','achtzehn']

def oddoreven(x):
    a = re.split('( Million )',name)
    b = re.split('(tausend)',a[-1])
    c = re.split('(hundret)',b[-1])
    d = re.split('und[a-z]+',c[-1])
    
    if len(d)>1:
        digit = d[0]
        print(digit)
        
        if digit in odds:
            result = 'odd'
        elif digit in evens:
            result = 'even'
        else:
            result = 'Error'
        return result
    
    elif len(c)>1:
        digit = c[-1]
        print(digit)
        
        if digit in odds:
            result = 'odd'
        elif digit in evens:
            result = 'even'
        else:
            result = 'Error'
        return result
  
    elif len(b)>1:
        digit = b[-1]
        print(digit)
        
        if digit in odds:
            result = 'odd'
        elif digit in evens:
            result = 'even'
        else:
            result = 'Error'
        return result
    
    elif len(a)>1:
        digit = a[-1]
        print(digit)
        
        if digit in odds:
            result = 'odd'
        elif digit in evens:
            result = 'even'
        else:
            result = 'Error'
        return result
    
    else:
        return 'Length too short'

odd_even_tag = oddoreven(name)
print(odd_even_tag)
# Out:
# einhundretvier Million dreihundretfünfundneunzigtausenddreiundsechzig
# drei
# odd

# %%
# this is a better attempt
# there are some exceptions that don't work still, like dreizig is noted as 'odd' but should be 'even'
# I would need to add these exceptions in if statements, but I'm moving on because I've spent too much time on this

x = createNum2WordDict(1,1_000_000_000)
name = number_names(x)[0]
print(name)

def oddoreven2(x):
    
    odds = ['ein','eins','drei','fünf','sieben','neun','elf','sieb']
    evens = ['','zwei','vier','sechs','acht','zehn','zwolf','zwan']
    
    name_list = re.split('(.+(?<=Million))?(.+(?<=tausend))?(.+(?<=hundret))?',x)
    
    # I can now split my final digit on zehn or und+ or zig
    final_digit = re.split('zehn|und.+|zig',name_list[-1])
    print(final_digit[0])
    
    if final_digit[0] in odds:
        result = 'odd'
    elif final_digit[0] in evens:
        result = 'even'
    else:
        result = 'error'
    
    return result

odd_even_tag = oddoreven2(name)
print(odd_even_tag)
# Out:
# achthundretachtundachtzig Million neunhundretsiebenundfünfzigtausendvierhundretsechszehn
# sechs
# even
# /Users/garethjones/anaconda3/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
# Tal's solution
# create an odd number map. the ? denotes the character can exist or not
numMap = {
    1: 'eins?',
    3: 'drei',
    5: 'fünf',
    7: 'sieb(en)?',
    9: 'neun',
    11: 'elf'
}
reg = ('('+ ')|('.join(numMap.values()) +')')+'((zehn)|(und))?([zβ]ig)?$'
print(reg)
reg = re.compile(reg)
result = {x:reg.search(x) is not None for key,x in d.items()}
result
# Out:
# (eins?)|(drei)|(fünf)|(sieb(en)?)|(neun)|(elf)((zehn)|(und))?([zβ]ig)?$
# {'einundzwanzig Million vierhundretvierundneunzigtausendsechshundretvierzehn': True,
#  'zwei Million dreihundretachtundsechzigtausendfünfhundretsiebenundzwanzig': True,
#  'siebenundachtzig Million fünfhundretneunundzwanzigtausendachthundretsechsundneunzig': True,
#  'undsechzig Million dreiundachtzigtausendsechshundretneunundsechzig': True,
#  'siebenundfünfzig Million achthundretsiebenunddreiβigtausendfünfhundretunddreiβig': True,
#  'siebenundsiebzig Million vierhundretundsechzigtausendzweihundretvierundsiebzig': True,
#  'unddreiβig Million fünfhundretachtundfünfzigtausendvierhundretvierzehn': True,
#  'undachtzig Million sechshundreteinundachtzigtausendsiebenhundretsiebenundsechzig': True,
#  'undfünfzig Million fünfhundretvierundachtzigtausendsiebenhundretsiebenundvierzig': True,
#  'siebenunddreiβig Million fünfhundretundachtzigtausendachthundretfünfundneunzig': True,
#  'zweiundzwanzig Million einhundretzehntausendeinhundreteinundzwanzig': True,
#  'siebenundfünfzig Million dreihundretviertausendachthundretundvierzig': True,
#  'vierundvierzig Million vierhundretundfünfzigtausendneunhundretvierundsiebzig': True,
#  'neunundzwanzig Million neunhundretsechsundsechzigtausendsechshundretneunundneunzig': True,
#  'acht Million zweihundretundsechzigtausenddreihundretvierundsiebzig': True,
#  'zwei Million neunhundreteinundzwanzigtausendsechshundretzwei': True,
#  'dreizehn Million zweihundretdreizehntausendvierhundretdreiundsechzig': True,
#  'achtundfünfzig Million dreihundretsechsundsechzigtausendzweihundretachtunddreiβig': True,
#  'achtundneunzig Million achthundretdreiundfünfzigtausendeinhundretachtundsechzig': True,
#  'einundsiebzig Million neunhundretundfünfzigtausendfünfhundretvierundzwanzig': True,
#  'neunundfünfzig Million neunhundretsechstausendvierhundretein': True,
#  'zwei Million einhundretsiebentausendsechshundretdreiundachtzig': True,
#  'sechsundachtzig Million vierhundretdreizehntausendsechshundretvierundneunzig': True,
#  'einundsiebzig Million zweihundreteinundfünfzigtausendzweihundretneunundzwanzig': True,
#  'undsechzig Million fünfhundretfünfundfünfzigtausendneununddreiβig': True,
#  'dreiundfünfzig Million neunhundreteinundneunzigtausendeinhundretsechsunddreiβig': True,
#  'siebenunddreiβig Million zweihundreteinunddreiβigtausendsiebenhundretvier': True,
#  'sechs Million vierhundretfünfundvierzigtausenddreihundretdreiundsechzig': True,
#  'einzehn Million zweihundretsechstausendvierhundretsechsundfünfzig': True,
#  'dreiundachtzig Million zweihundreteinundsiebzigtausendvierhundretfünfundvierzig': True,
#  'undsechzig Million fünfhundretsechszehntausendzweihundretdreiundneunzig': True,
#  'dreiundzwanzig Million neunhundreteinundsiebzigtausendachthundretfünfunddreiβig': True,
#  'dreiundsechzig Million fünfhundreteinundachtzigtausendachthundretdreiundsiebzig': True,
#  'siebenundneunzig Million einhundretfünfundachtzigtausendsechshundretacht': True,
#  'zweiundsiebzig Million achthundreteintausendsechshundretvierzehn': True,
#  'achtundfünfzig Million dreihundretsiebenundsiebzigtausenddreihundretsiebenundsechzig': True,
#  'dreiundfünfzig Million einhundretdreiunddreiβigtausendeinhundretacht': True,
#  'vierunddreiβig Million siebenhundretdreitausendzweihundretfünfundzwanzig': True,
#  'undachtzig Million vierhundretdreiundsiebzigtausendsiebenhundreteinzehn': True,
#  'fünfundfünfzig Million achthundretundsiebzigtausendsechshundretdrei': True,
#  'dreizehn Million neunhundretvierundfünfzigtausendsiebenhundretundneunzig': True,
#  'siebenundsiebzig Million dreihundretdreizehntausendzweihundretachtzehn': True,
#  'siebenundneunzig Million siebenhundretsechsundneunzigtausendsiebenhundretsechsundvierzig': True,
#  'sechsunddreiβig Million vierhundreteinundvierzigtausendachthundretneunzehn': True,
#  'zweiundsechzig Million einhundretzweiundneunzigtausendeinundsechzig': True,
#  'fünfundachtzig Million sechshundretundvierzigtausenddreihundretzehn': True,
#  'achtundneunzig Million siebenunddreiβigtausendachthundretsiebenzehn': True,
#  'undzwanzig Million dreihundretsiebenundsechzigtausendsechsundsechzig': True,
#  'fünfundsechzig Million fünfhundretdreiundzwanzigtausendneunhundretzweiundzwanzig': True,
#  'neunundneunzig Million einhundretvierundachtzigtausenddreihundretsiebenzehn': True,
#  'zweiundsechzig Million siebenundzwanzigtausenddreihundretvierundzwanzig': True,
#  'sechsundzwanzig Million siebenhundretfünfundsechzigtausendachthundretvierundsiebzig': True,
#  'vierundzwanzig Million sechshundretsiebenundzwanzigtausendeinhundretfünfundvierzig': True,
#  'sechszehn Million zehntausendsechshundretvierzehn': False,
#  'neunundachtzig Million achthundretsiebenundsechzigtausenddreihundretsiebenundachtzig': True,
#  'achtundsechzig Million neunhundretsiebentausendsechshundretsiebenundvierzig': True,
#  'vier Million zweihundreteinundsiebzigtausendzweiundachtzig': True,
#  'zweiundvierzig Million neunhundretsiebenundvierzigtausenddreihundretneunundfünfzig': True,
#  'vierundvierzig Million achthundreteinundsiebzigtausendzweihundreteinundvierzig': True,
#  'sechsundzwanzig Million achthundretsiebenundzwanzigtausendsiebenhundretsiebenundfünfzig': True,
#  'siebenundfünfzig Million zweihundreteinundzwanzigtausendachthundreteinundsiebzig': True,
#  'sieben Million achthundretvierundzwanzigtausendeinhundretsiebenundsiebzig': True,
#  'fünfundsiebzig Million fünfhundretzweiundsiebzigtausendneunhundreteinundvierzig': True,
#  'fünfzehn Million neunhundretsechsundneunzigtausendzweihundretneunundneunzig': True,
#  'zweiundsechzig Million dreihundretdreiundfünfzigtausendeinhundretsieben': True,
#  'neunundfünfzig Million fünfhundretneunundfünfzigtausenddreihundretvier': True,
#  'sechs Million achthundretvierundsechzigtausenddreihundretundsechzig': True,
#  'sechsundfünfzig Million zweihundretundachtzigtausendsechshundretsiebenundneunzig': True,
#  'fünfundzwanzig Million undachtzigtausenddreihundretundzwanzig': True,
#  'zweizehn Million einhundretvierundneunzigtausendsiebenhundretvierundvierzig': True,
#  'fünfundvierzig Million dreihundrettausendeinhundretachtundneunzig': True,
#  'zweiundzwanzig Million zweihundretdreiundvierzigtausendzweihundretzweizehn': True,
#  'dreiundsechzig Million neunhundretsiebenundfünfzigtausendachthundreteinundneunzig': True,
#  'siebenunddreiβig Million neunhundretachtundachtzigtausendvierhundret': True,
#  'fünfundsechzig Million siebenhundreteinundsechzigtausendfünfhundretfünfundvierzig': True,
#  'einundfünfzig Million einhundretzweiundzwanzigtausendvierhundretfünfundneunzig': True,
#  'einundsechzig Million einhundretsechsundvierzigtausendsechshundretfünf': True,
#  'unddreiβig Million fünfundvierzigtausendvierhundretdreiundfünfzig': True,
#  'vierundsechzig Million neunhundretdreizehntausendneunhundretfünfunddreiβig': True,
#  'fünfundsiebzig Million einhundretdreiundneunzigtausendfünfundzwanzig': True,
#  'einundzwanzig Million vierhundretundsechzigtausendzweihundretsiebenundzwanzig': True,
#  'undvierzig Million fünfhundretzweiundvierzigtausendfünfhundretdreiundfünfzig': True,
#  'siebenundfünfzig Million einhundretsiebenundachtzigtausendfünfhundretdreiundsiebzig': True,
#  'zweiundachtzig Million einhundretsiebenundvierzigtausendfünfhundreteinundsiebzig': True,
#  'dreiunddreiβig Million achtundvierzigtausendeinhundretsieben': True,
#  'vierundachtzig Million sechshundretdreiundachtzigtausenddreihundretneunundneunzig': True,
#  'neunundfünfzig Million zweihundretfünfzehntausendfünfhundretachtundneunzig': True,
#  'sechsundachtzig Million sechshundretneunzehntausendsiebenhundretdreiundfünfzig': True,
#  'vierundzwanzig Million neunhundretvierundvierzigtausendsechshundretsiebenundsiebzig': True,
#  'fünfundneunzig Million achthundretsechsundsiebzigtausendfünfhundretundachtzig': True,
#  'einundsechzig Million siebenhundretsiebenundzwanzigtausendsiebenhundretsechsundsiebzig': True,
#  'undsiebzig Million sechshundreteinundsiebzigtausendfünfhundretfünfundachtzig': True,
#  'undsechzig Million zweihundretundsiebzigtausendsiebenhundretacht': True,
#  'achtundsechzig Million neunhundretsechszehntausendsechshundretzweiundsiebzig': True,
#  'dreiundachtzig Million vierhundretvierundsiebzigtausendfünfhundretdreiundvierzig': True,
#  'zweiundzwanzig Million achtundsiebzigtausendneunhundretundzwanzig': True,
#  'zweiundachtzig Million siebenhundretzweiundneunzigtausendsechshundretvier': True,
#  'siebenunddreiβig Million fünfhundreteinundsechzigtausendachthundretdreiundneunzig': True,
#  'undneunzig Million dreihundretfünftausendzweihundretdreizehn': True,
#  'neunundneunzig Million vierhundretsiebenundfünfzigtausendzweihundretzweiundneunzig': True,
#  'vierundsiebzig Million fünfhundretsechsundsiebzigtausendfünfhundretsechsundsiebzig': True,
#  'einundfünfzig Million vierhundretfünftausendfünfhundreteinundfünfzig': True,
#  'zweiundvierzig Million neunhundretachttausendsiebenhundretneunzehn': True,
#  'vierundsiebzig Million einhundretvierundsiebzigtausendsechshundretachtundsiebzig': True,
#  'dreiundsechzig Million siebentausendneunhundretneunundfünfzig': True,
#  'einundzwanzig Million sechshundretzweiundzwanzigtausendneunhundretsiebenzehn': True,
#  'fünfundsiebzig Million sechsundsiebzigtausendvierhundretsiebenundneunzig': True,
#  'vierundvierzig Million sechshundretachtundfünfzigtausendachthundretsechsundzwanzig': True,
#  'vierundachtzig Million neunundsechzigtausendfünfhundretneunundvierzig': True,
#  'undzwanzig Million neunhundretzweiundzwanzigtausenddreihundretdreiundsechzig': True,
#  'achtundsiebzig Million vierhundretachtunddreiβigtausenddreihundretsechsundachtzig': True,
#  'siebenundsechzig Million zweihundretsiebenzehntausenddreihundretsechs': True,
#  'sechsundfünfzig Million vierhundretvierunddreiβigtausendzweiundzwanzig': True,
#  'zehn Million dreiundsechzigtausendzweihundretsiebenundachtzig': True,
#  'neunundvierzig Million eintausendsiebenhundretneununddreiβig': True,
#  'zweiundneunzig Million zweihundretdreiundneunzigtausendvierhundreteinundsiebzig': True,
#  'achtundneunzig Million dreihundretfünfundvierzigtausendzweihundretvierundsiebzig': True,
#  'vierundsiebzig Million einhundretvierundneunzigtausendneunhundretachtundvierzig': True,
#  'siebenundvierzig Million achthundreteinundzwanzigtausendneunhundretsechszehn': True,
#  'achtundsechzig Million dreihundretneuntausendsiebenhundretundsechzig': True,
#  'undsiebzig Million achthundreteinundsiebzigtausendachthundreteinundsechzig': True,
#  'neununddreiβig Million zweihundretdreizehntausendachthundretdreiundzwanzig': True,
#  'sechszehn Million undneunzigtausenddreihundretundachtzig': True,
#  'neununddreiβig Million einhundretzweiundsiebzigtausendvierhundretsiebenundsechzig': True,
#  'neunundvierzig Million fünfhundretsiebenzehntausendachthundreteinundsechzig': True,
#  'einundsechzig Million neunhundreteinundsiebzigtausendvierhundretachtzehn': True,
#  'undachtzig Million sechshundreteintausendsiebenhundreteinundneunzig': True,
#  'neunundvierzig Million dreihundretvierundsiebzigtausendachtundneunzig': True,
#  'einundzwanzig Million zweihundretfünfundfünfzigtausendzweihundret': True,
#  'fünf Million fünfhundretneunundsechzigtausenddreihundretsiebenundsiebzig': True,
#  'fünfunddreiβig Million fünfhundretsiebenundachtzigtausendsechshundretdreiundzwanzig': True,
#  'siebenundneunzig Million neunhundretachtundachtzigtausendvierhundretvierunddreiβig': True,
#  'undfünfzig Million fünfhundretvierundvierzigtausendzweihundretfünfundsiebzig': True,
#  'fünfundsechzig Million zweihundretsechsundvierzigtausendvierhundretsiebenundsechzig': True,
#  'neunundachtzig Million fünfhundretdreitausendachthundretneunundsechzig': True,
#  'einundzwanzig Million dreihundretdreiunddreiβigtausendachthundretfünfundvierzig': True,
#  'neunundsiebzig Million sechshundretneunundsechzigtausendsiebenhundretfünfundachtzig': True,
#  'siebenundvierzig Million einhundretfünfundvierzigtausendeinhundretsechsundsechzig': True,
#  'vierundzwanzig Million zweihundretzweiundfünfzigtausendneunhundretzweiundneunzig': True,
#  'fünfundsechzig Million zweihundretundsiebzigtausendeinhundretvier': True,
#  'siebenundvierzig Million sechshundretundsechzigtausendzweihundretsiebenundachtzig': True,
#  'zweiundzwanzig Million dreihundretsiebenundzwanzigtausendsiebenhundretundvierzig': True,
#  'fünfundfünfzig Million dreihundretzweitausendsiebenhundretfünfunddreiβig': True,
#  'undsiebzig Million undfünfzigtausendvierhundretsechsundneunzig': True,
#  'achtundsiebzig Million achthundretsechsundvierzigtausendvierundsechzig': True,
#  'neunundneunzig Million zweihundreteinundvierzigtausendsiebenhundretfünfunddreiβig': True,
#  'vierundzwanzig Million sechsundsechzigtausendvierhundretachtunddreiβig': True,
#  'neunundachtzig Million fünfundsechzigtausendzwei': True,
#  'sechsundzwanzig Million neunhundretachtundzwanzigtausendzweiundneunzig': True,
#  'undfünfzig Million siebenhundretsechsundsiebzigtausendsiebenhundretzweiunddreiβig': True,
#  'neunundsechzig Million einhundretzweitausendvierhundretvierundfünfzig': True,
#  'einzehn Million dreihundretachtundneunzigtausendsiebenhundretachtundneunzig': True,
#  'fünf Million dreihundreteinundvierzigtausendeinhundretneun': True,
#  'neunzehn Million dreihundreteinundneunzigtausendsechsundneunzig': True,
#  'achtundsiebzig Million sechshundretachtundvierzigtausendachthundretachtundneunzig': True,
#  'dreiundzwanzig Million zweihundretfünfundsiebzigtausendzweihundretachtundsiebzig': True,
#  'acht Million zweihundretzweiundsechzigtausendsiebenhundretneunundsechzig': True,
#  'fünfzehn Million siebenhundretsiebenunddreiβigtausenddreihundretundsechzig': True,
#  'dreiundzwanzig Million einhundretsechszehntausenddreihundretachtundzwanzig': True,
#  'fünfzehn Million zweihundretneunzehntausendeinhundretfünfunddreiβig': True,
#  'einundvierzig Million einhundretachtundsechzigtausendeinhundretvier': True,
#  'siebenundvierzig Million dreihundreteinundsechzigtausendeinhundreteinunddreiβig': True,
#  'vierundsiebzig Million dreihundretfünfundfünfzigtausendzweihundretundachtzig': True,
#  'neunundvierzig Million dreihundretdreiundsechzigtausendeinunddreiβig': True,
#  'sechsundsechzig Million achthundretundvierzigtausendzweihundretneun': True,
#  'dreiundfünfzig Million achthundretdreiundsiebzigtausendachthundretein': True,
#  'undsechzig Million einundvierzigtausendzweihundretdreiundsechzig': True,
#  'sechsundsiebzig Million vierhundretsechstausendsiebenhundretneunundsiebzig': True,
#  'undfünfzig Million einhundretneuntausenddreihundretdreiundsiebzig': True,
#  'sechs Million einhundretzweizehntausendeinhundreteinundsiebzig': True,
#  'sechsunddreiβig Million siebenhundretneunundsiebzigtausendsiebenhundretundzwanzig': True,
#  'zweiundzwanzig Million dreihundretzweiundsiebzigtausendsechshundretsechsundsiebzig': True,
#  'dreiundachtzig Million einhundretzweiundneunzigtausendzweihundreteinundfünfzig': True,
#  'achtundzwanzig Million einhundretfünfundzwanzigtausendzweiundzwanzig': True,
#  'vierundvierzig Million fünfhundretachttausendsechshundretneunundsechzig': True,
#  'siebenunddreiβig Million achthundretzweiundsiebzigtausendfünfhundretfünfundneunzig': True,
#  'siebenundfünfzig Million einhundretsiebenundsechzigtausendzweihundretsiebenundzwanzig': True,
#  'undfünfzig Million einhundretvierundneunzigtausendneunhundretneunundzwanzig': True,
#  'zweiundneunzig Million achthundretunddreiβigtausendsiebenhundretfünfundneunzig': True,
#  'vier Million siebenundsechzigtausenddreihundretvierundsechzig': True,
#  'neunundsechzig Million dreihundretsiebenundzwanzigtausendsiebenhundretsechsundzwanzig': True,
#  'vierundsiebzig Million dreihundretzweiundsechzigtausendsiebenhundretsechsunddreiβig': True,
#  'dreiundvierzig Million einhundretzweiunddreiβigtausendsiebenhundretundzwanzig': True,
#  'vierundvierzig Million sechshundreteinundfünfzigtausendeinunddreiβig': True,
#  'einundsechzig Million vierhundretsiebenundsechzigtausendsechshundretachtundneunzig': True,
#  'ein Million vierhundreteinundsiebzigtausendsechshundretneunzehn': True,
#  'einundsechzig Million sechsundzwanzigtausendzweihundretfünfundfünfzig': True,
#  'neun Million achthundretzehntausendsiebenhundretsiebenundvierzig': True,
#  'neunundsiebzig Million neunhundretvierzehntausendsiebenhundretsiebenundsechzig': True,
#  'dreiundfünfzig Million einhundretundachtzigtausendeinhundretundvierzig': True,
#  'einunddreiβig Million zweihundretundfünfzigtausendsechshundreteinunddreiβig': True,
#  'sechsunddreiβig Million neunhundretfünfundsiebzigtausendneunhundretneununddreiβig': True,
#  'ein Million vierhundretachttausendsiebenhundreteinundzwanzig': True,
#  'siebenundsechzig Million siebenhundretfünfundachtzigtausendsiebenhundretachtundneunzig': True,
#  'achtundachtzig Million siebenhundretvierundvierzigtausendzweihundretvierundvierzig': True,
#  'achtundachtzig Million neunhundretachtundzwanzigtausendachthundretsiebenundzwanzig': True,
#  'sechsundsechzig Million neunhundretvierundachtzigtausenddreiunddreiβig': True,
#  'siebenundvierzig Million dreihundretvierunddreiβigtausendneunhundretein': True,
#  'einunddreiβig Million siebenhundrettausendachthundretsiebenundsiebzig': True,
#  'ein Million neunhundretdreiundzwanzigtausendsechshundretzweiundzwanzig': True,
#  'ein Million achthundretzweiunddreiβigtausendeinhundretdreiundsiebzig': True,
#  'vier Million zweihundreteinunddreiβigtausendsechshundretachtundsiebzig': True,
#  'sechs Million siebenhundretfünfzehntausendneunhundreteinunddreiβig': True,
#  'einundachtzig Million einhundretsiebenundvierzigtausendvierhundretdreiundzwanzig': True,
#  'achtundsechzig Million dreiunddreiβigtausendsiebenhundretsieben': True,
#  'dreiundneunzig Million einhundrettausendsechshundretdreiunddreiβig': True,
#  'sieben Million vierhundretundzwanzigtausendsiebenhundretfünfundsiebzig': True,
#  'neunundsechzig Million dreihundretsechszehntausendsechshundretachtundvierzig': True,
#  'ein Million achthundretdreitausendvierhundretfünfundsiebzig': True,
#  'fünfunddreiβig Million zweihundreteinundfünfzigtausendachthundretzweiundsechzig': True,
#  'zehn Million fünfundzwanzigtausendvierhundretzweiundvierzig': True,
#  'fünfundachtzig Million fünfhundreteinundsiebzigtausendvierhundretneunundachtzig': True,
#  'achtundsiebzig Million einhundreteinundneunzigtausenddreihundretneunundachtzig': True,
#  'sechsundsechzig Million achthundretunddreiβigtausendneunhundretsechszehn': True,
#  'neunundfünfzig Million siebenhundretfünfundfünfzigtausendachthundretdreiundsechzig': True,
#  'fünfundsiebzig Million fünfundneunzigtausendzweihundretsechsundzwanzig': True,
#  'undzwanzig Million zweihundretneunundvierzigtausendfünfhundretzwei': True,
#  'siebenundfünfzig Million sechshundretvierundneunzigtausendvierhundretneunundvierzig': True,
#  'sechsundfünfzig Million fünfhundretachtundvierzigtausendneunhundretsiebenzehn': True,
#  'siebenundvierzig Million vierhundretachtundsiebzigtausendzweihundretachtundsiebzig': True,
#  'sechsundsiebzig Million achthundretsechsundfünfzigtausendsiebenhundretdreiundfünfzig': True,
#  'dreiundachtzig Million sechshundretneunzehntausendsechshundretvierundvierzig': True,
#  'dreiundsiebzig Million dreihundretzweitausendzweihundretvierunddreiβig': True,
#  'vier Million einhundretvierundvierzigtausendsiebenhundretachtundzwanzig': True,
#  'sechs Million dreihundretfünfundzwanzigtausendeinhundretsiebenundsiebzig': True,
#  'fünfundsiebzig Million achthundreteinundachtzigtausendsiebenhundretsechsundfünfzig': True,
#  'fünfundneunzig Million achthundretachtundneunzigtausendneunhundretvierundfünfzig': True,
#  'siebenundsechzig Million vierhundretneunundzwanzigtausendeinhundretneunundfünfzig': True,
#  'zweiundzwanzig Million achthundretsechsundzwanzigtausendvierhundretsiebenundzwanzig': True,
#  'neunzehn Million sechshundretsiebentausendsiebenhundretsiebenundzwanzig': True,
#  'fünfzehn Million fünfhundretvierundzwanzigtausenddreihundretdreiundsechzig': True,
#  'neunundachtzig Million vierhundretachtundsiebzigtausendzwei': True,
#  'neununddreiβig Million fünfhundretundachtzigtausendvierhundret': True,
#  'vierundneunzig Million fünfhundretneuntausendzweihundretsechs': True,
#  'siebenundachtzig Million einhundretsiebenundsiebzigtausendsechshundretsechsundsechzig': True,
#  'zweiundsechzig Million zweihundreteinunddreiβigtausendzweiundzwanzig': True,
#  'sieben Million neunhundretvierundsechzigtausendzweihundretneunundzwanzig': True,
#  'sechsundsechzig Million neunundfünfzigtausendsechshundretzweiundsechzig': True,
#  'sechsundvierzig Million siebenhundretachtundachtzigtausendfünfhundretvierundsiebzig': True,
#  'fünfundvierzig Million neunhundretachtundzwanzigtausendvierhundretundsiebzig': True,
#  'siebenundsiebzig Million sechshundretachtundachtzigtausendzweihundretfünfundzwanzig': True,
#  'einundneunzig Million einhundretzehntausendfünfhundretvierundneunzig': True,
#  'achtundsechzig Million sechshundretzweitausendzweihundretachtundfünfzig': True,
#  'dreiundfünfzig Million siebenhundretsechsundfünfzigtausendeinhundreteinunddreiβig': True,
#  'sechsundfünfzig Million siebenhundretfünftausendzweihundretzweiundfünfzig': True,
#  'undfünfzig Million neunundfünfzigtausendzweihundretneunundsechzig': True,
#  'dreiunddreiβig Million sechshundretachtundsiebzigtausendsechshundretzweiunddreiβig': True,
#  'sechsundzwanzig Million fünfhundretneunzehntausenddreiundneunzig': True,
#  'zweiundachtzig Million einhundretzweiundzwanzigtausendsechshundretvierzehn': True,
#  'undfünfzig Million achthundretfünfundvierzigtausendachthundretzweiundsechzig': True,
#  'dreiundachtzig Million einhundretsiebenzehntausendvierhundretfünfzehn': True,
#  'sechsundneunzig Million dreihundretneunundfünfzigtausendzweihundretachtundsiebzig': True,
#  'zweiundneunzig Million siebenhundretdreiunddreiβigtausendvierhundretdreiundsiebzig': True,
#  'zweizehn Million einhundretdreiundachtzigtausendsechshundretzweiundzwanzig': True,
#  'neun Million dreihundretsechsundzwanzigtausendsiebenhundretacht': True,
#  'undfünfzig Million einhundretfünfzehntausenddreihundretvierundsiebzig': True,
#  'achtundneunzig Million zweihundretachtzehntausendneunhundretsiebenundfünfzig': True,
#  'siebenundfünfzig Million fünfhundretachtundzwanzigtausendvierzehn': True,
#  'vierundzwanzig Million fünfhundretundzwanzigtausendvierhundretdreiundneunzig': True,
#  'achtundfünfzig Million sechshundretneunundzwanzigtausendeinhundretvierundsechzig': True,
#  'drei Million einhundretdreiundfünfzigtausendzweihundretzweiundvierzig': True,
#  'zweiundachtzig Million fünfhundretfünftausendvierhundretfünfundachtzig': True,
#  'fünfundneunzig Million achthundreteinundsechzigtausendachthundretzehn': True,
#  'sechshundretvierundsiebzigtausendeinhundretsiebenundsiebzig': True,
#  'zweiundfünfzig Million sechshundretfünfundvierzigtausendachthundretundfünfzig': True,
#  'achtundneunzig Million dreihundretundachtzigtausendachthundreteinundfünfzig': True,
#  'dreiundsechzig Million dreihundretvierunddreiβigtausendsiebenhundretsechsundsiebzig': True,
#  'einundneunzig Million einhundretsiebenundneunzigtausendeinhundreteinundfünfzig': True,
#  'einundneunzig Million fünfhundretneunundneunzigtausendvierhundretneununddreiβig': True,
#  'zehn Million siebenhundretachtundneunzigtausendzweihundretein': True,
#  'zweiundsechzig Million sechshundretneuntausendvierhundretsiebenundachtzig': True,
#  'neun Million fünfhundretfünfundvierzigtausendfünfhundreteinzehn': True,
#  'ein Million sechshundretzweiundvierzigtausenddreihundretsiebenundneunzig': True,
#  'zweiundvierzig Million sechshundretsechstausendsiebenhundretneunundfünfzig': True,
#  'neunzehn Million zweihundretzweiundsechzigtausendsiebenhundretvierundsechzig': True,
#  'unddreiβig Million dreihundretsechsunddreiβigtausendvierhundretsechsundsiebzig': True,
#  'undneunzig Million vierhundretachtzehntausendeinhundretneun': True,
#  'fünf Million einhundretachtzehntausendsiebenhundretsieben': True,
#  'einundvierzig Million achthundretzweiundvierzigtausenddreihundretsechs': True,
#  'undfünfzig Million vierhundretsechsundachtzigtausendsechshundretzweiundfünfzig': True,
#  'zweiundsiebzig Million zweihundretsechsundzwanzigtausendvierhundretundneunzig': True,
#  'einundneunzig Million neununddreiβigtausendachthundretsechsundneunzig': True,
#  'einundsechzig Million neunhundretundachtzigtausendneunhundretein': True,
#  'neunundfünfzig Million einhundretzweiundvierzigtausendsiebenhundretsiebenundzwanzig': True,
#  'dreizehn Million vierhundretachtzehntausendfünfhundretfünfundfünfzig': True,
#  'siebenundachtzig Million fünfundvierzigtausendzweihundretdreiundachtzig': True,
#  'undsiebzig Million zweihundretdreiundvierzigtausendsechszehn': True,
#  'ein Million achthundretsechszehntausendeinhundretneunundachtzig': True,
#  'undneunzig Million sechshundretsechsunddreiβigtausendvierhundretsiebenundfünfzig': True,
#  'achtundfünfzig Million achthundretzehntausendsiebenhundreteinundsiebzig': True,
#  'vierundsechzig Million zweihundretsiebenunddreiβigtausendvierhundretneunundzwanzig': True,
#  'neunundvierzig Million sechshundretdreiundvierzigtausendvierhundretdreiundvierzig': True,
#  'drei Million zweihundretfünfundachtzigtausendsechshundretachtunddreiβig': True,
#  'zweiundvierzig Million dreihundretsechszehntausendsiebenhundretdrei': True,
#  'fünfzehn Million fünfhundretvierundvierzigtausendvierhundretvierundzwanzig': True,
#  'fünfundvierzig Million zweihundretzweiundsiebzigtausendvierhundretvier': True,
#  'zweiundsechzig Million achthundretsiebenundachtzigtausendvierhundretsechsundachtzig': True,
#  'achtundachtzig Million neunundsiebzigtausendsechshundreteinundsechzig': True,
#  'zweiundzwanzig Million einhundretdreiundneunzigtausendsechshundretdreiunddreiβig': True,
#  'undzwanzig Million dreihundretachtzehntausenddreihundretachtundsechzig': True,
#  'fünfundachtzig Million siebenhundretsiebenzehntausendneunhundretsiebenundachtzig': True,
#  'achtundsechzig Million einhundretneunzehntausendeinhundretzweiunddreiβig': True,
#  'dreiundsiebzig Million fünfhundretachtundvierzigtausendfünfhundretsechsundzwanzig': True,
#  'einundfünfzig Million einhundretdreiundsiebzigtausendachtundsechzig': True,
#  'siebenundsechzig Million sechsundfünfzigtausendfünfhundretachtundfünfzig': True,
#  'einundneunzig Million neunhundretundzwanzigtausendneunhundretundzwanzig': True,
#  'vierzehn Million neunhundretzweiundsiebzigtausendsiebenhundretfünfundvierzig': True,
#  'vier Million dreihundretdreizehntausenddreihundretachtundachtzig': True,
#  'sechsundsiebzig Million siebenhundretachtundsechzigtausendundvierzig': True,
#  'fünfundsiebzig Million einundfünfzigtausendvierhundretvier': True,
#  'zweiunddreiβig Million sechshundretviertausendneunhundretsiebenundsechzig': True,
#  'einundachtzig Million fünfhundretsiebenundzwanzigtausendvierhundreteinundfünfzig': True,
#  'dreizehn Million vierhundretfünfundzwanzigtausendfünfhundreteinundfünfzig': True,
#  'dreiundachtzig Million vierhundretsiebenundzwanzigtausendsechshundretvierundsiebzig': True,
#  'zweiundfünfzig Million einhundretachtundsiebzigtausendsiebenundsiebzig': True,
#  'drei Million sechshundretdreiundzwanzigtausendneunhundretdreiundvierzig': True,
#  'undneunzig Million fünfhundretsechsundsechzigtausendsechsundachtzig': True,
#  'dreiundzwanzig Million siebenhundretneununddreiβigtausendzweihundretdreizehn': True,
#  'dreiundfünfzig Million siebenhundreteinundsechzigtausendachthundretneunundachtzig': True,
#  'undachtzig Million zweihundreteinundfünfzigtausendsiebenhundretdreiundsechzig': True,
#  'neunzehn Million achthundretsechsundsechzigtausenddreihundretvierundsiebzig': True,
#  'sechs Million achthundretsiebenzehntausenddreizehn': True,
#  'zweiundsiebzig Million fünfhundretfünfzehntausendsiebenhundretsiebenundfünfzig': True,
#  'siebenundfünfzig Million siebenhundretdreizehntausendsiebenhundretneunundsiebzig': True,
#  'achtundachtzig Million vierhundretsiebenundneunzigtausendsechshundretvierundzwanzig': True,
#  'dreiundzwanzig Million neunhundretzweiundvierzigtausendvierhundretvierundfünfzig': True,
#  'neunundvierzig Million zweihundretsechszehntausendneunhundretzweiundneunzig': True,
#  'vierundsiebzig Million achthundretvierundneunzigtausendachthundretneunundzwanzig': True,
#  'drei Million einhundretneunundzwanzigtausendzweihundretachtundvierzig': True,
#  'neunundneunzig Million einhundretviertausenddreihundreteinundneunzig': True,
#  'fünfundfünfzig Million fünfunddreiβigtausendvierhundretachtundneunzig': True,
#  'fünfundsechzig Million einhundretdreiundsechzigtausendzweihundretneunundneunzig': True,
#  'siebenundsechzig Million siebenhundretdreiundfünfzigtausendacht': True,
#  'einundneunzig Million dreihundretvierundzwanzigtausendeinhundretzweizehn': True,
#  'dreiundvierzig Million vierhundretzweiundfünfzigtausendvierhundretsechsundneunzig': True,
#  'achtundneunzig Million neunhundreteinundsechzigtausendsiebenhundretundzwanzig': True,
#  'undvierzig Million achthundretvierundneunzigtausendfünfhundretsechsundsiebzig': True,
#  'ein Million vierhundretundsechzigtausendzweihundretzweiundachtzig': True,
#  'siebenundvierzig Million siebenhundretundachtzigtausendachthundretzweiundneunzig': True,
#  'zweiundsechzig Million neunundachtzigtausendneunundvierzig': True,
#  'vierzehn Million fünfhundretzehntausenddreiundzwanzig': True,
#  'siebenhundretdreiundachtzigtausendzweihundretfünfzehn': True,
#  'sechsundachtzig Million einhundretundsiebzigtausendsiebenhundretsiebenundneunzig': True,
#  'dreiundvierzig Million fünfhundretneunundvierzigtausendsiebenhundretsechsundachtzig': True,
#  'zweiundzwanzig Million dreihundretzweiundzwanzigtausendneunhundretacht': True,
#  'einunddreiβig Million siebenhundretachtundvierzigtausendsechshundretdreiunddreiβig': True,
#  'undvierzig Million siebenhundretsiebenzehntausendfünfhundretachtundsiebzig': True,
#  'fünfundzwanzig Million siebenhundretfünfundneunzigtausendachthundretundachtzig': True,
#  'achtundfünfzig Million einhundretzweizehntausendvierhundretachtunddreiβig': True,
#  'fünfundfünfzig Million dreihundreteinundsiebzigtausendsechshundretsiebenundvierzig': True,
#  'vierundachtzig Million siebenundneunzigtausendeinundsiebzig': True,
#  'sechs Million zweihundreteinunddreiβigtausendvierhundretfünfzehn': True,
#  'achtundsiebzig Million siebenhundretvierzehntausendneunhundreteinunddreiβig': True,
#  'undvierzig Million dreiundvierzigtausendvierhundretachtundsiebzig': True,
#  'siebenundvierzig Million zweihundretneuntausendsechshundretfünf': True,
#  'dreiundachtzig Million sechszehntausendfünfhundretdreizehn': True,
#  'sechsundneunzig Million einhundretundneunzigtausendzweihundretzweiundvierzig': True,
#  'fünfundneunzig Million zweihundretdreizehntausendvierhundretzweiundsiebzig': True,
#  'fünf Million vierhundretachtundzwanzigtausendneunhundretsiebenzehn': True,
#  'vierundzwanzig Million zweiundvierzigtausendeinundzwanzig': True,
#  'achtundzwanzig Million sechshundreteinundfünfzigtausendneunhundretundneunzig': True,
#  'vier Million neunhundretvierundsiebzigtausendeinhundretfünfzehn': True,
#  'siebenunddreiβig Million neunhundretsechsundneunzigtausendachthundretdreiunddreiβig': True,
#  'zweiundneunzig Million undsiebzigtausendvierhundretvierundsechzig': True,
#  'sechsundachtzig Million achthundreteinundsechzigtausenddreihundretneununddreiβig': True,
#  'dreiundneunzig Million siebenhundretzweiundvierzigtausenddreihundretsechsundzwanzig': True,
#  'einundfünfzig Million achthundreteinundneunzigtausenddreihundretsechsundvierzig': True,
#  'achtundsechzig Million siebenhundreteinundzwanzigtausendsechshundretsiebenundachtzig': True,
#  'siebenundvierzig Million fünfhundretfünfzehntausendsiebenhundretsiebenundneunzig': True,
#  'vierundsechzig Million dreihundreteinundvierzigtausendachthundretneunundfünfzig': True,
#  'achtundzwanzig Million fünfhundretdreiundachtzigtausendsechshundretzweiundachtzig': True,
#  'sechsundfünfzig Million dreihundretzweiundsiebzigtausendsiebenundneunzig': True,
#  'neunundfünfzig Million zweiundachtzigtausendneunhundretundsiebzig': True,
#  'dreiundneunzig Million fünfhundretsiebenundneunzigtausendsechshundretachtundfünfzig': True,
#  'sechsundzwanzig Million neunhundretneunzehntausendfünfhundretvier': True,
#  'fünfundsechzig Million einundfünfzigtausendsiebenhundretdreiundachtzig': True,
#  'vierundsechzig Million undsechzigtausenddreihundretzweizehn': True,
#  'achtundfünfzig Million vierhundreteinundfünfzigtausendfünfhundretsechs': True,
#  'zweiundsechzig Million vierhundretviertausendeinhundretsiebenundachtzig': True,
#  'siebenundvierzig Million achthundretsiebenzehntausendfünfundvierzig': True,
#  'einundachtzig Million dreihundretsechstausendneunhundretneunzehn': True,
#  'siebenundachtzig Million fünfhundretvierundvierzigtausendachthundretvierundachtzig': True,
#  'siebenundzwanzig Million zweihundretneuntausendsechshundreteinundneunzig': True,
#  'dreiundvierzig Million dreihundretfünfundneunzigtausendvierhundretsechszehn': True,
#  'sechsundzwanzig Million fünfhundretsiebenundfünfzigtausendsechshundret': True,
#  'zweiundsechzig Million sechshundretneuntausenddreihundretsiebenundachtzig': True,
#  'undvierzig Million einhundretneunundachtzigtausendzweihundretvierzehn': True,
#  'vierundachtzig Million zweihundretsiebenundsiebzigtausendfünfhundretsechsunddreiβig': True,
#  'fünfundfünfzig Million siebenhundretvierundvierzigtausendvierhundretsechsundsechzig': True,
#  'achtundachtzig Million siebenhundretzweiundsiebzigtausendsechshundretsiebenunddreiβig': True,
#  'vierundsiebzig Million sechshundretsiebentausendeinundneunzig': True,
#  'undzwanzig Million zweihundretsechsunddreiβigtausendvierhundretundneunzig': True,
#  'siebenzehn Million sechshundretfünfundfünfzigtausendzweihundretvierundfünfzig': True,
#  'zweiundfünfzig Million neunhundretzweiundsiebzigtausendsechshundretfünfzehn': True,
#  'undsiebzig Million vierhundretachtunddreiβigtausendvierhundretfünfzehn': True,
#  'sechsundachtzig Million achthundretsechsundsechzigtausendeinhundretachtundzwanzig': True,
#  'neunundsiebzig Million siebenhundretundsiebzigtausenddreihundretfünfunddreiβig': True,
#  'drei Million einhundretneunundneunzigtausendeinhundretzweiundsiebzig': True,
#  'fünfzehn Million vierhundretfünfundachtzigtausendsiebenhundretzweiundsiebzig': True,
#  'dreiundvierzig Million zweiundzwanzigtausendachthundretsieben': True,
#  'zweiundfünfzig Million fünfhundretundfünfzigtausendsechshundretdreizehn': True,
#  'acht Million vierhundretsiebenunddreiβigtausendsiebenhundretzweiundachtzig': True,
#  'vierundzwanzig Million vierhundretdreiundsiebzigtausendsechshundreteinundneunzig': True,
#  'vierzehn Million vierhundretdreiunddreiβigtausendachthundretfünfunddreiβig': True,
#  'unddreiβig Million vierundfünfzigtausendneunhundretsiebenundachtzig': True,
#  'dreiundvierzig Million siebenundachtzigtausendfünfhundretdreizehn': True,
#  'undzwanzig Million zweiundzwanzigtausendsiebenundvierzig': True,
#  'dreiundvierzig Million neunhundretzweiundachtzigtausenddreihundretvierundneunzig': True,
#  'neunundfünfzig Million neunzehntausendsiebenhundretsechsundachtzig': True,
#  'zweiundneunzig Million siebenundvierzigtausendfünfhundretundfünfzig': True,
#  'dreiundfünfzig Million neunhundretneunundfünfzigtausendneunhundretachtundzwanzig': True,
#  'vierunddreiβig Million achthundreteinundsechzigtausendneunhundretsiebenundvierzig': True,
#  'neun Million neunhundretdreitausendvierhundretvierunddreiβig': True,
#  'undsechzig Million siebenhundretundneunzigtausendfünfhundretfünfundzwanzig': True,
#  'siebenundfünfzig Million vierhundretdreizehntausendeinhundretsechsundfünfzig': True,
#  'einundfünfzigtausenddreihundretachtundachtzig': True,
#  'siebenundachtzig Million sechshundretsiebenundsechzigtausendsiebenhundretfünfundneunzig': True,
#  'neunundvierzig Million sechsundsiebzigtausendeinundvierzig': True,
#  'zweizehn Million dreihundretdreiundzwanzigtausendvierhundretvierundneunzig': True,
#  'fünfundzwanzig Million zweizehntausendfünfhundretzehn': True,
#  'vierhundretundsechzigtausendachthundretachtzehn': False,
#  'siebenunddreiβig Million vierhundretzweiundsiebzigtausendvierhundreteinundzwanzig': True,
#  'achtundsechzig Million neunhundretneunundfünfzigtausendsechshundretzweizehn': True,
#  'dreiundzwanzig Million neunhundretundvierzigtausendsechshundretfünfundneunzig': True,
#  'sechs Million siebenhundretneunundneunzigtausendsiebenhundretvierundsechzig': True,
#  'sechsunddreiβig Million vierhundretzweiunddreiβigtausendsiebenhundretachtunddreiβig': True,
#  'siebenundzwanzig Million vierhundretzweizehntausendeinhundretachtundneunzig': True,
#  'fünfzehn Million vierhundreteinundsiebzigtausendsechshundreteinundachtzig': True,
#  'zweiundvierzig Million einhundretvierundsechzigtausendsechshundret': True,
#  'neunundachtzig Million achthundretzehntausendvierhundretsechsundachtzig': True,
#  'sechsundfünfzig Million vierhundretsechsundneunzigtausendeinhundretzweiundsiebzig': True,
#  'neunundsechzig Million einhundretneununddreiβigtausendsechshundretzweiundzwanzig': True,
#  'zweiundzwanzig Million neunhundretneunundzwanzigtausendsiebenhundretsiebenundzwanzig': True,
#  'siebenzehn Million dreihundretneunundsechzigtausendachthundretdreiundfünfzig': True,
#  'neununddreiβig Million sechshundretvierundsechzigtausendfünfhundretachtundachtzig': True,
#  'drei Million dreihundretneunundvierzigtausendfünfhundretvierundfünfzig': True,
#  'neunundneunzig Million einhundretzweiundachtzigtausendsiebenhundretachtundvierzig': True,
#  'undsechzig Million achthundrettausendundachtzig': False,
#  'undneunzig Million vierhundretneunundzwanzigtausendzweihundretzweiundvierzig': True,
#  'sechsundsiebzig Million dreihundretsiebenundsechzigtausendachthundretachtundvierzig': True,
#  'siebenunddreiβig Million neunhundreteinundvierzigtausendzweihundretneunundsechzig': True,
#  'vier Million neunhundretunddreiβigtausendfünfhundretachtzehn': True,
#  'fünfundsiebzig Million neunhundretzweiundsiebzigtausendsechshundretsieben': True,
#  'siebenundsiebzig Million zweihundretfünfzehntausenddreihundretdreiundachtzig': True,
#  'zweiundneunzig Million fünfundachtzigtausendvierhundretzweizehn': True,
#  'sechsunddreiβig Million achthundretfünfundachtzigtausendeinhundretachtundsechzig': True,
#  'neun Million fünfundzwanzigtausendvierhundreteinundneunzig': True,
#  'neunundachtzig Million dreihundreteinundzwanzigtausendsechshundretneunzehn': True,
#  'undzwanzig Million zweihundretundzwanzigtausendachthundretvierundsechzig': False,
#  'einzehn Million einhundretundachtzigtausendsiebenundsechzig': True,
#  'siebenundneunzig Million zweihundretdreiundsiebzigtausendvierhundretneunundzwanzig': True,
#  'siebenundzwanzig Million dreihundretdreiundachtzigtausendsechshundretdreiundsiebzig': True,
#  'zweiundachtzig Million achthundreteinundvierzigtausendsiebenhundretvierundvierzig': True,
#  'siebenundachtzig Million dreihundretsiebenundzwanzigtausendsiebenhundretvierundachtzig': True,
#  'vierunddreiβig Million achthundretvierundsechzigtausendneunhundreteinzehn': True,
#  'siebenundvierzig Million dreihundretachtzehntausendneunhundretneunundsiebzig': True,
#  'siebenundachtzig Million neunhundreteinundachtzigtausendfünfhundreteinundvierzig': True,
#  'einunddreiβig Million fünfhundretdreiundachtzigtausendsiebenhundretsiebenundvierzig': True,
#  'sechsundneunzig Million fünfhundretachtundneunzigtausendvierhundretzehn': True,
#  'dreiundvierzig Million achthundretvierundsechzigtausendsechshundretvierundsechzig': True,
#  'neun Million neunhundretsechsundneunzigtausendachthundretsechsunddreiβig': True,
#  'vierundzwanzig Million zweihundretvierundsechzigtausend': False,
#  'einundzwanzig Million einhundretdreiundachtzigtausendeinhundretsechs': True,
#  'zweiunddreiβig Million sechshundretundneunzigtausendeinhundretsiebenundzwanzig': True,
#  'vierunddreiβig Million fünfhundretundsechzigtausendzweihundretvierundfünfzig': True,
#  'einundsiebzig Million neunhundretdreiundsechzigtausendneunhundretvierundsechzig': True,
#  'fünfundsechzig Million neunhundretachtundfünfzigtausendsiebenhundretundachtzig': True,
#  'sechsundachtzig Million neunhundretzweiundzwanzigtausendzweiundneunzig': True,
#  'undfünfzig Million achthundretsiebenzehntausenddreihundretzwei': True,
#  'sechsundzwanzig Million dreihundretsiebenunddreiβigtausendzweiundachtzig': True,
#  'sechsundvierzig Million achthundretdreiundsechzigtausendzweihundretvier': True,
#  'neunundachtzig Million sechshundretvierunddreiβigtausendsiebenhundretundvierzig': True,
#  'siebenzehn Million sechshundreteinzehntausendeinhundretacht': True,
#  'einundneunzig Million einhundreteinundneunzigtausendsechshundretsechsundneunzig': True,
#  'zweiunddreiβig Million zweihundretachtundsechzigtausendachthundretdreiundsechzig': True,
#  'siebenzehn Million vierhundretneununddreiβigtausendneunhundretfünfunddreiβig': True,
#  'neunundsiebzig Million fünfhundretzweiundvierzigtausendzweiundfünfzig': True,
#  'neunundzwanzig Million neunhundretneunzehntausendsechshundretsiebenundachtzig': True,
#  'neununddreiβig Million achtunddreiβigtausendfünfhundretneun': True,
#  'fünfundachtzig Million siebenhundretdreiunddreiβigtausendneunhundretfünfundvierzig': True,
#  'sechszehn Million zweihundretundachtzigtausendachthundretdreiundsiebzig': True,
#  'vierundfünfzig Million siebenhundretneununddreiβigtausendsiebenhundretsiebenundvierzig': True,
#  'sechsundzwanzig Million sechshundretneunundsechzigtausendachthundretvierundsechzig': True,
#  'einundachtzig Million dreihundretsiebenundsechzigtausendeinhundretfünfundsechzig': True,
#  'siebenunddreiβig Million einhundretdreitausendvierhundret': True,
#  'einunddreiβig Million fünfunddreiβigtausendachthundretsechsundfünfzig': True,
#  'neunzehn Million vierhundretachtzehntausendfünfhundretzweiundfünfzig': True,
#  'vierundzwanzig Million neunhundretsiebenundfünfzigtausendsiebenhundretvierundzwanzig': True,
#  'sechs Million einhundreteinunddreiβigtausendachthundretachtunddreiβig': True,
#  'einundsiebzig Million siebenhundretfünfzehntausenddreihundretneununddreiβig': True,
#  'achtundvierzig Million dreiundvierzigtausendeinhundretneunundsiebzig': True,
#  'zweiundsiebzig Million vierhundretsiebenundsiebzigtausendzweihundretvierundachtzig': True,
#  'sieben Million siebenhundretzweitausenddreihundretvierundsechzig': True,
#  'neunundvierzig Million fünfundzwanzigtausendsiebenhundretneunundneunzig': True,
#  'dreiundsiebzig Million fünfhundretdreiundachtzigtausendfünfhundretachtundneunzig': True,
#  'fünfundfünfzig Million dreihundretzehntausendsiebenhundreteinundfünfzig': True,
#  'undvierzig Million fünfhundretdreiundsechzigtausendvierhundretzweizehn': True,
#  'einundneunzig Million fünfhundretvierundvierzigtausendneunhundretdreiundvierzig': True,
#  'zweiundzwanzig Million fünfhundretfünfzehntausendsiebenhundretundneunzig': True,
#  'neunundachtzig Million dreihundretundvierzigtausendzweihundretunddreiβig': True,
#  'neunundzwanzig Million neunhundretachtunddreiβigtausendachthundretneunundsiebzig': True,
#  'undachtzig Million achtzehntausendsechshundretsiebenundfünfzig': True,
#  'einundsechzig Million vierhundretfünfundzwanzigtausendfünfhundretsiebenundzwanzig': True,
#  'siebenundfünfzig Million sechshundretsiebenundachtzigtausendeinhundretundzwanzig': True,
#  'achtundsechzig Million zweiundfünfzigtausendfünfhundretvierundsiebzig': True,
#  'einunddreiβig Million neunhundretneunundvierzigtausendneunhundretneununddreiβig': True,
#  'zweiundsiebzig Million vierunddreiβigtausendsechshundretvier': True,
#  'siebenundneunzig Million sechshundreteinundneunzigtausendzweihundretdreiunddreiβig': True,
#  'siebenunddreiβig Million dreihundretdreizehntausenddreihundretneunundsechzig': True,
#  'siebenundsechzig Million zweihundretzweiundfünfzigtausendvierhundretsiebenundfünfzig': True,
#  'undneunzig Million achthundretneunundneunzigtausendneunhundretvierzehn': True,
#  'siebenundzwanzig Million sechsundzwanzigtausendsiebenhundretsechsundsechzig': True,
#  'dreiundfünfzig Million vierhundretdreiundachtzigtausendzweiundsechzig': True,
#  'neununddreiβig Million achthundretfünfundachtzigtausendsechshundretachtunddreiβig': True,
#  'sechsundzwanzig Million fünfundsiebzigtausendeinhundreteinunddreiβig': True,
#  'neunundneunzig Million dreihundretneunundvierzigtausendsiebenhundretsieben': True,
#  'zweiundvierzig Million vierhundretzweiundzwanzigtausenddreihundretzehn': True,
#  'sechsundneunzig Million sechshundretfünfunddreiβigtausendzweihundretsechsunddreiβig': True,
#  'undzwanzig Million sechsundzwanzigtausendzweihundreteinundsechzig': True,
#  'fünfundvierzig Million achthundretsechszehntausendfünfhundreteinzehn': True,
#  'siebenundfünfzig Million sechshundretzehntausendsechshundretsiebenundzwanzig': True,
#  'sechsundachtzig Million neunundfünfzigtausendsiebenhundretachtundneunzig': True,
#  'vierundfünfzig Million vierhundretachtundneunzigtausendzweihundretachtundfünfzig': True,
#  'sechszehn Million einhundreteinundachtzigtausendzweihundretfünfundzwanzig': True,
#  'siebenundsiebzig Million zweihundretneunundsechzigtausenddreihundretzweiundfünfzig': True,
#  'sechsundsiebzig Million neunhundretfünfzehntausendvierundfünfzig': True,
#  'fünfundachtzig Million einhundretzweitausendfünfhundretdreiundsiebzig': True,
#  'neunzehn Million viertausendachthundretachtundzwanzig': True,
#  'sechsunddreiβig Million einhundretvierunddreiβigtausendzweihundretvierundneunzig': True,
#  'sechsundneunzig Million zweihundretneunundachtzigtausendneunhundretsechsundvierzig': True,
#  'neununddreiβig Million zweihundretsechszehntausendzweiunddreiβig': True,
#  'zweiundneunzig Million undachtzigtausendneunhundretfünfundvierzig': True,
#  'vier Million sechshundretsiebentausendvierhundretsechsundachtzig': True,
#  'zweiundzwanzig Million fünfhundretdreiundachtzigtausendneunhundretneunzehn': True,
#  'vierzehn Million sechshundretdreiundfünfzigtausendeinhundretneununddreiβig': True,
#  'zweiunddreiβig Million sechshundretachtzehntausendsiebenhundreteinunddreiβig': True,
#  'vierundachtzig Million achthundreteinzehntausendfünfundneunzig': True,
#  'vier Million vierhundretachtundvierzigtausendvierhundretachtundzwanzig': False,
#  'fünfundneunzig Million fünfhundretzweiundneunzigtausendzweihundretsieben': True,
#  'acht Million einhundretvierunddreiβigtausendachthundretachtundvierzig': True,
#  'sieben Million dreihundretsiebenundneunzigtausendfünfhundretneunundsiebzig': True,
#  'zweiundfünfzig Million vierhundretfünftausendvierhundretein': True,
#  'sechsundsiebzig Million einhundretfünfundvierzigtausenddreihundretundsechzig': True,
#  'zwei Million sechshundretneunundachtzigtausendsiebenhundretvierundvierzig': True,
#  'neunundzwanzig Million einhundretfünfundneunzigtausendneunhundreteinundfünfzig': True,
#  'sechsundsechzig Million fünfhundretundneunzigtausendzweihundretsechsundsiebzig': True,
#  'zweizehn Million vierhundretneunundsechzigtausendachtundneunzig': True,
#  'dreiundachtzig Million achthundretsechsunddreiβigtausendfünfhundretsiebenundvierzig': True,
#  'dreizehn Million vierhundretneunundvierzigtausendzweihundretsechsundzwanzig': True,
#  'zweiundsiebzig Million dreihundretsiebentausendneunhundretsechsundachtzig': True,
#  'siebenundsiebzig Million sechshundretundsiebzigtausendfünfhundretzweiundneunzig': True,
#  'acht Million siebenhundretsechszehntausenddreihundretsechsunddreiβig': True,
#  'zwei Million vierhundretfünfundvierzigtausendachthundretzweiundachtzig': True,
#  'achtundzwanzig Million dreihundreteinundzwanzigtausendneunhundretfünfzehn': True,
#  'achtundzwanzig Million fünfhundretsiebenundfünfzigtausendfünfhundretsechsundsiebzig': True,
#  'siebenundvierzig Million siebenhundretachtundvierzigtausendvierhundretundsiebzig': True,
#  'dreiundsiebzig Million achthundretachtzehntausendsechshundretsechsundsechzig': True,
#  'zweizehn Million einhundretzweiundvierzigtausendvierhundretachtzehn': True,
#  'vier Million achthundretneunundachtzigtausendvierhundretsechsundsechzig': True,
#  'drei Million zweitausenddreihundretsechsundzwanzig': True,
#  'neunundvierzig Million fünfhundretvierundfünfzigtausendeinhundret': True,
#  'fünfundsiebzig Million siebenhundretsiebenundvierzigtausendachthundreteinundsiebzig': True,
#  'sechsunddreiβig Million vierhundretsechsundneunzigtausendeinhundretsechsundachtzig': True,
#  'einundneunzig Million dreihundretsechszehntausendachthundreteinundneunzig': True,
#  'sechs Million einhundretzweiundachtzigtausendzweihundretundsiebzig': True,
#  'fünfundvierzig Million sechshundretvierundachtzigtausenddreihundretachtunddreiβig': True,
#  'dreiundsiebzig Million achthundretundzwanzigtausenddreihundretsechszehn': True,
#  'dreiundfünfzig Million siebenundvierzigtausendsiebenundachtzig': True,
#  'achtzehn Million fünfhundretzweiundsiebzigtausendeinhundretvierundneunzig': True,
#  'siebenundsiebzig Million achthundretundfünfzigtausendzweihundreteinundneunzig': True,
#  'zweiundvierzig Million dreihundretdreiundvierzigtausendachthundretsechszehn': True,
# ...
#  'vierundsiebzig Million fünfhundretzehntausendsiebenhundretsiebenundachtzig': True,
#  'siebenundneunzig Million sechshundretunddreiβigtausendachthundretneunundfünfzig': True,
#  'neunzehn Million achthundreteinundachtzigtausendzweihundretsechs': True,
#  'einundneunzig Million achthundretundachtzigtausendsiebenhundretundvierzig': True,
#  'dreizehn Million dreihundretfünfzehntausendsechshundretdreiundsechzig': True,
#  'vierundneunzig Million dreihundretfünfunddreiβigtausendzweihundretvierundfünfzig': True,
#  'sechsundneunzig Million sechshundreteinundvierzigtausendneunhundretvierundsechzig': True,
#  'einundzwanzig Million siebenundvierzigtausendachthundretfünfzehn': True,
#  'zweiunddreiβig Million einhundreteinundvierzigtausendneunhundretein': True,
#  'sechsundsiebzig Million sechshundretfünfundsechzigtausendzweihundretdrei': True,
#  'neunundzwanzig Million achthundreteinundvierzigtausendfünfzehn': True,
#  'fünfundachtzig Million dreiundneunzigtausenddreihundretvierzehn': True,
#  'neunundsiebzig Million sechshundretsechsundsechzigtausendzweihundretvierzehn': True,
#  'einundsiebzig Million dreihundretdreiundachtzigtausendneunhundretacht': True,
#  'achtundfünfzig Million siebenhundretvierundachtzigtausendneunhundretdreiundfünfzig': True,
#  'zweizehn Million dreihundretdreiundvierzigtausendzweihundret': True,
#  'neunundsiebzig Million vierundsechzigtausendzweiundvierzig': True,
#  'vierundsechzig Million neunhundretneunundsiebzigtausendsiebenhundretsechs': True,
#  'achtundvierzig Million dreihundretvierundzwanzigtausendeinhundretzweiunddreiβig': True,
#  'acht Million einundneunzigtausenddreihundretdreiundsechzig': True,
#  'sechszehn Million einhundretneunundsiebzigtausenddreihundretneunundvierzig': True,
#  'zweiundsechzig Million sechshundreteinundsiebzigtausendfünfhundretzweiundsechzig': True,
#  'zweizehn Million siebenhundretachtundvierzigtausendvierhundretneunundzwanzig': True,
#  'vier Million achthundretdreiundneunzigtausendsiebenhundretdreiundneunzig': True,
#  'achtundsechzig Million dreihundretneunundvierzigtausendzweihundreteinzehn': True,
#  'fünfundfünfzig Million achthundreteinundsechzigtausendeinhundretsechsundsiebzig': True,
#  'sechsundfünfzig Million siebenhundretundvierzigtausendfünfhundretundsiebzig': True,
#  'dreiunddreiβig Million vierhundretsechsundzwanzigtausendachthundretfünfundsiebzig': True,
#  'fünf Million neuntausendsiebenhundretsechs': True,
#  'einundfünfzig Million achthundretneunundfünfzigtausendachthundretvierundachtzig': True,
#  'achtundvierzig Million siebenhundretsechsundsiebzigtausendsiebenhundretunddreiβig': True,
#  'siebenundsechzig Million einhundreteinundsiebzigtausendneunhundretdreiundzwanzig': True,
#  'vierundfünfzig Million zweihundretfünfzehntausendachthundretzwei': True,
#  'ein Million achthundretzweiunddreiβigtausendneunhundretfünf': True,
#  'zweiundachtzig Million fünfhundreteinundvierzigtausendachtzehn': True,
#  'dreiundfünfzig Million einhundretachtundfünfzigtausendfünfhundretvierundsechzig': True,
#  'sechsundsiebzig Million neunhundretfünfundneunzigtausendfünfhundretzweizehn': True,
#  'achtundachtzig Million siebenhundretfünfundzwanzigtausendvierhundretdreiundsiebzig': True,
#  'neunundzwanzig Million neunhundretachtundsechzigtausendachthundretachtundsiebzig': True,
#  'einundfünfzig Million neunhundretvierundachtzigtausendfünfhundretsiebenundsechzig': True,
#  'undachtzig Million siebenhundretsechsundsechzigtausendzweihundretfünfundfünfzig': True,
#  'sechsundachtzig Million vierhundretneunundvierzigtausendneunhundretfünfundsechzig': True,
#  'siebenzehn Million einhundretfünfundfünfzigtausendsechshundretzweiundfünfzig': True,
#  'achtzehn Million siebenhundretzweiundneunzigtausendeinhundreteinundzwanzig': True,
#  'achtundsiebzig Million dreihundretfünfundfünfzigtausendneunhundretdreizehn': True,
#  'undsiebzig Million neunhundretdreiundzwanzigtausendsechshundretvierundsechzig': True,
#  'sechsundsiebzig Million zweihundretvierunddreiβigtausendvierhundretzweiundvierzig': True,
#  'sechsundachtzig Million dreiunddreiβigtausendachthundretfünfundfünfzig': True,
#  'undsechzig Million siebenhundretsechszehntausendeinhundretneunundzwanzig': True,
#  'sieben Million sechshundretvierundzwanzigtausendsiebenhundretvierundzwanzig': True,
#  'neun Million viertausendvierhundretundneunzig': True,
#  'zwei Million neunhundretachtundneunzigtausendvierhundretsechszehn': True,
#  'siebenundvierzig Million achttausendzweihundretvierundachtzig': True,
#  'einunddreiβig Million siebenhundretsiebenundsechzigtausendvierhundretsiebenundsiebzig': True,
#  'einundzwanzig Million dreiunddreiβigtausenddreihundretundsechzig': True,
#  'undneunzig Million zweihundretachtundsechzigtausendeinhundretfünfunddreiβig': True,
#  'einundsechzig Million undsechzigtausenddreihundretsiebenzehn': True,
#  'sechsundachtzig Million siebenhundretvierundvierzigtausendsechshundretundvierzig': True,
#  'dreiundvierzig Million dreihundreteinundneunzigtausendzweihundretsechsundsechzig': True,
#  'fünf Million zweihundretsechstausendfünfhundretvierundfünfzig': True,
#  'dreiundzwanzig Million zweihundretdreizehntausendneunhundretundzwanzig': True,
#  'fünfunddreiβig Million achthundretzweitausendneunhundretzweizehn': True,
#  'siebenzehn Million sechshundretfünfzehntausendachthundretzweizehn': True,
#  'dreiundsiebzig Million siebenundachtzigtausendachthundretfünf': True,
#  'siebenundsiebzig Million fünfhundretundfünfzigtausendachthundretfünfundvierzig': True,
#  'zweiundzwanzig Million neunhundretundsiebzigtausenddreihundretachtundachtzig': True,
#  'vierundneunzig Million fünfhundretunddreiβigtausendachthundretzweiundzwanzig': True,
#  'neunundneunzig Million einhundretneunundvierzigtausendneunhundreteinundachtzig': True,
#  'vierzehn Million neunhundreteinundsechzigtausendsechshundretsechsundachtzig': True,
#  'zweiundfünfzig Million dreiundzwanzigtausendneunhundretunddreiβig': True,
#  'vier Million sechshundretundsiebzigtausenddreihundretsiebenundachtzig': True,
#  'einundachtzig Million einhundretsechstausendneunhundretvierzehn': True,
#  'neunundfünfzig Million einhundretundvierzigtausenddreihundreteinundsechzig': True,
#  'sechsundachtzig Million einhundretdreizehntausendachthundreteinundneunzig': True,
#  'dreiundfünfzig Million vierhundretdreiunddreiβigtausenddreihundretein': True,
#  'sechszehn Million sechshundretneunundachtzigtausendeinhundreteinzehn': True,
#  'vierunddreiβig Million siebenhundretsiebenzehntausendeinhundretachtundzwanzig': True,
#  'siebenunddreiβig Million fünfhundretdreiundsiebzigtausendsechshundretachtundneunzig': True,
#  'neunundachtzig Million sechshundretfünfundachtzigtausendfünfhundretzweiundneunzig': True,
#  'sechsundsechzig Million einhundretundfünfzigtausendsechshundretsiebenundachtzig': True,
#  'neununddreiβig Million vierhundretdreiundachtzigtausendneunhundreteinundfünfzig': True,
#  'neunundfünfzig Million dreiundfünfzigtausendeinhundretacht': True,
#  'ein Million zweihundretdreitausendfünfhundretfünfunddreiβig': True,
#  'dreiundzwanzig Million fünfhundretsiebenundfünfzigtausendachthundreteinundneunzig': True,
#  'dreiundvierzig Million sechshundretneunundneunzigtausendzweihundretdreiundsiebzig': True,
#  'neun Million dreihundretundfünfzigtausendeinhundretvierzehn': True,
#  'drei Million vierhundreteintausendachthundretsieben': True,
#  'dreiundzwanzig Million achthundretundsechzigtausenddreihundretacht': True,
#  'vierzehn Million dreihundretsechsundfünfzigtausenddreihundretachtundsechzig': True,
#  'dreiundneunzig Million sechsundsiebzigtausendachthundretundsechzig': True,
#  'siebenundneunzig Million vierhundretundneunzigtausendundneunzig': True,
#  'dreizehn Million fünfundneunzigtausendfünfhundretzweiunddreiβig': True,
#  'vierundsiebzig Million fünfhundretfünfundvierzigtausendachthundretfünfundfünfzig': True,
#  'vierundzwanzig Million neunhundretfünfundsiebzigtausenddreihundretundneunzig': True,
#  'sechs Million sechshundretdreiundfünfzigtausendeinhundretneunundneunzig': True,
#  'sechsundsechzig Million dreihundretsechsundfünfzigtausendzweihundretzweiundsechzig': True,
#  'sechsundachtzig Million siebenhundretundvierzigtausendneunhundretfünfundsiebzig': True,
#  'sechsundsechzig Million dreihundretviertausendneunhundretsiebenunddreiβig': True,
#  'einunddreiβig Million siebenhundretundsiebzigtausendsiebenhundretsiebenundsiebzig': True,
#  'einundfünfzig Million sechshundreteintausendneunhundretdrei': True,
#  'zwei Million fünfhundretsiebenundneunzigtausendfünfhundretvierundachtzig': True,
#  'dreiundachtzig Million fünfhundretdreiunddreiβigtausendvierhundretsechsundneunzig': True,
#  'dreiunddreiβig Million vierhundreteinundsiebzigtausendfünfhundretfünfundsiebzig': True,
#  'vier Million achthundretachtundzwanzigtausendsiebenhundretzweiundfünfzig': True,
#  'zweiundfünfzig Million dreihundretsechsundsiebzigtausendneunhundretachtundsechzig': True,
#  'neunundneunzig Million zweihundretdreiundfünfzigtausendfünfhundreteinunddreiβig': True,
#  'zweiundsiebzig Million fünfhundretsechsundvierzigtausenddreihundretfünfundsechzig': True,
#  'acht Million siebenhundretvierundsechzigtausendzweihundretachtundsiebzig': True,
#  'fünfundzwanzig Million neunhundretsechstausendsiebenhundretdreiundsiebzig': True,
#  'sechsundvierzig Million neunhundretsechszehntausenddreihundretfünfundneunzig': True,
#  'siebenundvierzig Million einhundretzweiundachtzigtausendsechshundretdreiundvierzig': True,
#  'siebenundsechzig Million vierhundretzweiundzwanzigtausendachthundretzweizehn': True,
#  'zweiundzwanzig Million achthundretneunundzwanzigtausendeinhundretsechsundneunzig': True,
#  'vierzehn Million einhundretzweiundvierzigtausendachthundretachtundachtzig': True,
#  'zweiunddreiβig Million neunhundreteinundneunzigtausendvierhundreteinundsechzig': True,
#  'einundzwanzig Million vierhundretneunundvierzigtausenddreihundretneunundsechzig': True,
#  'einzehn Million neunhundretdreizehntausendfünfundfünfzig': True,
#  'siebenundfünfzig Million vierhundretzweiundachtzigtausendvierhundretdreiundvierzig': True,
#  'undsiebzig Million siebenhundretdreiundzwanzigtausendsechshundretdreiundsiebzig': True,
#  'unddreiβig Million einhundretzweiundfünfzigtausendzweihundretneunundzwanzig': True,
#  'neunundsechzig Million neunhundretachttausendzweihundretsiebenunddreiβig': True,
#  'fünfunddreiβig Million siebenhundretachtundachtzigtausendsechshundreteinzehn': True,
#  'vierundvierzig Million dreihundretfünfundfünfzigtausendneunhundretvierundneunzig': True,
#  'fünfundneunzig Million zweihundreteinundneunzigtausendfünfhundretsieben': True,
#  'einundsiebzig Million dreihundretdreizehntausendzweihundreteinunddreiβig': True,
#  'siebenundneunzig Million achthundretsiebenundvierzigtausendzweiundsiebzig': True,
#  'neunundvierzig Million einhundretneunundneunzigtausendachthundretfünfundzwanzig': True,
#  'sechs Million einhundretundzwanzigtausendsiebenhundretvierundfünfzig': True,
#  'siebenundachtzig Million sechshundretsiebenundsiebzigtausendvierhundretfünfundsiebzig': True,
#  'neunhundretsechsunddreiβigtausendvierhundretsechsundsechzig': True,
#  'einunddreiβig Million einhundretsiebenundneunzigtausendeinhundretfünf': True,
#  'einundzwanzig Million fünfhundreteintausendsechshundretzweiundsechzig': True,
#  'dreiunddreiβig Million zweihundretvierundneunzigtausendsechshundretdreiundsechzig': True,
#  'fünfunddreiβig Million fünfhundreteinundachtzigtausendvierhundreteinundachtzig': True,
#  'zehn Million sechshundretzweiunddreiβigtausendachthundretzweiundzwanzig': True,
#  'ein Million neunundzwanzigtausendzweihundretvierundzwanzig': True,
#  'unddreiβig Million sechstausendachthundretneununddreiβig': True,
#  'dreiundachtzig Million neunhundretachtundsiebzigtausendsiebenhundretzweiunddreiβig': True,
#  'achtundneunzig Million neunhundretsiebenundsiebzigtausendeinhundretzweiundachtzig': True,
#  'dreiundsiebzig Million sechshundretneunundneunzigtausenddreihundretdreiundneunzig': True,
#  'achtundsiebzig Million fünfhundretundzwanzigtausendsiebenzehn': True,
#  'sechs Million neunhundretsiebenundvierzigtausendvierhundretsechsundneunzig': True,
#  'neunundvierzig Million einhundretsiebenunddreiβigtausendsiebenhundretneunundfünfzig': True,
#  'neun Million vierhundretachtzehntausendsiebenhundretachtundzwanzig': True,
#  'vierundneunzig Million zweihundretdreiundvierzigtausendeinhundretsechsundachtzig': True,
#  'siebenundvierzig Million sechshundretundsechzigtausendachthundreteinzehn': True,
#  'dreiundzwanzig Million siebenhundretzehntausendvierhundreteinundneunzig': True,
#  'zehn Million achthundretvierundachtzigtausendeinhundretsechszehn': True,
#  'siebenundachtzig Million siebenhundretzweiundsiebzigtausendvierhundretdreiunddreiβig': True,
#  'sechszehn Million einhundretundsechzigtausendneunhundretvierunddreiβig': True,
#  'vierundneunzig Million vierhundreteinundsiebzigtausendachthundretfünfundneunzig': True,
#  'dreizehn Million achthundretsechszehntausendneunhundretvier': True,
#  'siebenunddreiβig Million einhundretunddreiβigtausendsechshundretfünfundsechzig': True,
#  'siebenundachtzig Million zweihundretvierunddreiβigtausenddreihundretdreiundvierzig': True,
#  'vierundneunzig Million neunhundretvierundzwanzigtausenddreihundretvierundvierzig': True,
#  'achtunddreiβig Million zweihundretsiebenundvierzigtausendachtzehn': True,
#  'einzehn Million fünfhundretfünfundzwanzigtausendsechshundretfünf': True,
#  'dreiundsiebzig Million siebenhundretfünfundneunzigtausendneunhundretzweiundsiebzig': True,
#  'sechsunddreiβig Million achthundretzweitausendzweihundretundfünfzig': True,
#  'drei Million achthundretsechszehntausendachthundretsechszehn': True,
#  'undsechzig Million dreihundretsechsundzwanzigtausendfünfundsechzig': True,
#  'dreiundsechzig Million zweihundretneunundsechzigtausendvierhundretein': True,
#  'zweiundsechzig Million einhundretzweiundzwanzigtausendneunhundretfünfundvierzig': True,
#  'vierundzwanzig Million sechshundreteinundneunzigtausendsiebenhundretfünf': True,
#  'neunundvierzig Million fünfhundretzweiundfünfzigtausendfünfhundretdreiundfünfzig': True,
#  'vier Million zweihundretfünftausendachthundretzweiundvierzig': True,
#  'zehn Million siebenhundretzweitausendfünfhundretsechszehn': True,
#  'fünfzehn Million achthundreteinundzwanzigtausendachthundretundsiebzig': True,
#  'zwei Million fünfhundretsechsundneunzigtausendzweihundretzehn': True,
#  'zweiundneunzig Million achthundretneunundzwanzigtausendachthundretzweiundachtzig': True,
#  'neunundsechzig Million achthundretfünfundsechzigtausendzweihundretzweizehn': True,
#  'fünfundvierzig Million neunhundreteinundfünfzigtausendvierhundretachtundzwanzig': True,
#  'vierundsechzig Million siebenhundretneunundvierzigtausendzweihundretzweiundfünfzig': True,
#  'neunundsiebzig Million sechshundretvierundachtzigtausendachthundretsechsundvierzig': True,
#  'neunundachtzig Million sechsundachtzigtausendneunhundretundzwanzig': True,
#  'neunundsechzig Million einhundreteinundsechzigtausendachthundretzweiundneunzig': True,
#  'siebenundneunzig Million vierhundretsechsundvierzigtausendeinhundretdreiundzwanzig': True,
#  'siebenundsechzig Million zweihundretsechsundsechzigtausendzweiundneunzig': True,
#  'achtunddreiβig Million achthundretneunundfünfzigtausendachthundretsechsundneunzig': True,
#  'neununddreiβig Million fünfhundretfünfunddreiβigtausendsechshundretachtunddreiβig': True,
#  'neunundsiebzig Million siebenhundretfünfundfünfzigtausendfünfhundreteinundzwanzig': True,
#  'fünfundzwanzig Million neunhundreteinundsechzigtausendzweihundretneun': True,
#  'zweiundneunzig Million zweihundretsiebenundfünfzigtausendsechshundretsechsundsechzig': True,
#  'zweiundsiebzig Million dreihundretsiebenundvierzigtausendeinhundretein': True,
#  'einundachtzig Million zweihundretneunzehntausendvierhundretsiebenundfünfzig': True,
#  'dreiunddreiβig Million sechshundretvierundsechzigtausendvierhundretzweiundsiebzig': True,
#  'einundvierzig Million dreihundretsechszehntausendeinhundretsechs': True,
#  'undfünfzig Million vierhundretsechsundvierzigtausenddreiundsiebzig': True,
#  'vierundachtzig Million neunhundretsechszehntausendsechshundretundvierzig': True,
#  'zweiundvierzig Million vierundsiebzigtausendsiebenundvierzig': True,
#  'dreiundneunzig Million fünfhundretsiebenundachtzigtausendzweihundretachtundneunzig': True}

# %%
# Tal's solution

# %% [markdown]
# # Excercise 5 - Named Capture Groups
# Use pythons named capture groups ([Explanation](https://www.regular-expressions.info/named.html)) ([Reference](https://docs.python.org/3/library/re.html#regular-expression-syntax)) To split a number into it's constituent parts as a dictionary.
# Use named capture groups, and the **groupdict** function to get a dictionary. For example
#
# ```python
#     match = yourRegex.search("zweihundretsechsundfünfzigtausendsiebenhundretfünfundneunzig")
#     match.groupdict()
#     >
#         {
#             "thousands" : "zweihundretsechsundfünfzig",
#             "hundreds" : "sieben",
#             "tens" :"neunzig",
#             "ones" : "fünf"
#         }
#
# ```

# %%
x = createNum2WordDict(1,1_000_000_000)
name = number_names(x)[0]

matchObj = re.search('((?P<millions>.+)(?<=Million))?((?P<thousands>.+)(?<=tausend))?((?P<hundred>.+)(?<=hundret))?(?P<tens>.+)?',
    name)

matchObj.groupdict()
# Out:
# {'hundred': 'zweihundret',
#  'millions': 'achthundretachtundneunzig Million',
#  'tens': 'einundfünfzig',
#  'thousands': ' fünfhundretsechsundsiebzigtausend'}
