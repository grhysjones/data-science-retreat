# %% [markdown]
# Credits to https://stackoverflow.com/questions/17784587/gradient-descent-using-python-and-numpy

# %%
# PYTHON 2
import numpy as np
from matplotlib import pyplot as plt
import random

# %%
def generateSample(N, variance=100):
    X = np.matrix(range(N)).T + 1
    X = np.hstack([np.matrix(np.ones(len(X))).T, X])
    Y = np.matrix([random.random() * variance + i * 10 + 900 for i in range(len(X))]).T
    return X, Y

# %%
lr_sgd = 0.00001
lr_gd = 0.0001
Epochs = 100

def fitModel_gradient(x, y):
    N = len(x)
    w = np.zeros((x.shape[1], 1))
    
    for i in range(Epochs):
        error = x * w - y
        gradient = (x.T * error) / N
        w = w - lr_gd * gradient
    return w

def fitModel_stochastic_gradient(x, y):
    N = len(x)
    w = np.zeros((x.shape[1], 1))
    
    for e in range(Epochs):
        for i in range(N):
            error = x[i] * w - y[i]
            gradient = x[i].T * error
            w = w - lr_sgd * gradient
    return w

# %%
def plotModel(x, y, w):
    plt.plot(x[:,1], y, "x")
    plt.plot(x[:,1], x * w, "r-")
    plt.show()

# %%
X, Y = generateSample(100)
w_gd = fitModel_gradient(X, Y)
w_sgd = fitModel_stochastic_gradient(X, Y)
plotModel(X,Y,w_gd)
plotModel(X,Y,w_sgd)

# %%
X.shape
# Out:
# (100, 2)

# %%
Y.shape
# Out:
# (100, 1)
