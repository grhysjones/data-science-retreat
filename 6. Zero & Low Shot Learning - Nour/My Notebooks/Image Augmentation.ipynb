# %%
from keras import backend as K
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# read and plot image using mpimg (image path: data_aug/meerkat.jpg)

img = mpimg.imread('/Users/garethjones/Documents/Data Science/Data Science Retreat/Zero & Low Shot Learning - Nour/Nour-small-samples/notebooks/small_classifier/data_aug/meerkat.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
# use ImageDataGenerator from keras.preprocessing.image to generate different variations of the above image

from keras.preprocessing.image import ImageDataGenerator

img_gen = ImageDataGenerator()

transform_parameters = {
    'brightness': None,
    'channel_shift_intensity': None,
    'flip_horizontal': 0,
    'flip_vertical': 1,
    'shear': 0,
    'theta': 0,
    'tx': 0,
    'ty': 0,
    'zx': 1,
    'zy': 1}

img_vertical_flip = img_gen.apply_transform(img,transform_parameters)
plt.imshow(img_vertical_flip)
plt.show()
plt.close()

# %%
import numpy as np
x_train = np.array([img])
y_train = np.arrayS
